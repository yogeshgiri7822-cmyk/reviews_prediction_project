# %%
# !pip install cryptography
# Out:
# Collecting cryptography
#   Downloading cryptography-49.0.0-cp311-abi3-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from cryptography) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from cffi>=2.0.0->cryptography) (3.0)
# Downloading cryptography-49.0.0-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 1.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.0/3.8 MB 1.3 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/3.8 MB 1.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.6/3.8 MB 1.3 MB/s eta 0:00:02
#    ------------------- -------------------- 1.8/3.8 MB 1.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.1/3.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------ --------------- 2.4/3.8 MB 1.2 MB/s eta 0:00:02
#    --------------------------- ------------ 2.6/3.8 MB 1.3 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 1.2 MB/s eta 0:00:01
#    --------------------------------- ------ 3.1/3.8 MB 1.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 1.2 MB/s  0:00:03
# Installing collected packages: cryptography
# Successfully installed cryptography-49.0.0

# %%
# %pip install pymysql
# Out:
# Collecting pymysql
#   Using cached pymysql-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Using cached pymysql-1.2.0-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
conn=pymysql.connect(user='root',password='Root',host='localhost')
qur='create database rest_review_db'
mycur=conn.cursor()
mycur.execute(qur)
mycur.close()
conn.close()

# %%
import pymysql
conn=pymysql.connect(user='root',password='Root',host='localhost',
                             database='rest_review_db')
qur='''create table reviews_table(food VARCHAR(40) PRIMARY KEY ,
       good_review INT,
       bad_review INT,
       customer INT)'''


mycur=conn.cursor()
mycur.execute(qur)
mycur.close()
conn.close()

# %%
foods = ["Idly", "Dosa", "Vada", "Roti", "Meals", "Veg Biryani",
         "Egg Biryani", "Chicken Biryani", "Mutton Biryani",
         "Ice Cream", "Noodles", "Manchooriya", "Orange juice",
         "Apple Juice", "Pineapple juice", "Banana juice"]




for i in foods:
    conn=pymysql.connect(user='root',password='Root',host='localhost',
                         database='rest_review_db')
    qur='INSERT INTO reviews_table(food,good_review,bad_review,customer) VALUES("%s",%d,%d,%d)'%(i,0,0,0)
    mycur=conn.cursor()
    mycur.execute(qur)
    conn.commit()
    mycur.close()
    conn.close()
